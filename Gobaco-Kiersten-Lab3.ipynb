# %%
social_graph = {
    "@bongolpoc":{"first_name":"Joselito",
                  "last_name":"Olpoc",
                  "following":[
                  ]
    },
    "@joaquin":  {"first_name":"Joaquin",
                  "last_name":"Gonzales",
                  "following":[
                      "@chums","@jobenilagan"
                  ]
    },
    "@chums" : {"first_name":"Matthew",
                "last_name":"Uy",
                "following":[
                    "@bongolpoc","@miketan","@rudyang","@joeilagan"
                ]
    },
    "@jobenilagan":{"first_name":"Joben",
                   "last_name":"Ilagan",
                   "following":[
                    "@eeebeee","@joeilagan","@chums","@joaquin"
                   ]
    },
    "@joeilagan":{"first_name":"Joe",
                  "last_name":"Ilagan",
                  "following":[
                    "@eeebeee","@jobenilagan","@chums"
                  ]
    },
    "@eeebeee":  {"first_name":"Elizabeth",
                  "last_name":"Ilagan",
                  "following":[
                    "@jobenilagan","@joeilagan"
                  ]
    },
}


def relationship_status(from_member, to_member):
    following = False
    followedby = False
    if to_member in social_graph[from_member]["following"]:
        following=True
    if from_member in social_graph[to_member]["following"]:
        followedby=True
    if (following == True) and (followedby == True):
        return "friends"
    elif following == True:
        return "following"
    elif followedby == True:
        return "followed by"
    else:
        return None
        
print(relationship_status("@joeilagan","@chums"))
# Out:
# friends

# %%
board1 = [
['X','X','O'],
['O','X','O'],
['O','','X'],
]

board2 = [
['X','X','O'],
['O','X','O'],
['','O','X'],
]

board3 = [
['O','X','O'],
['','O','X'],
['X','X','O'],
]

board4 = [
['X','X','X'],
['O','X','O'],
['O','','O'],
]

board5 = [
['X','X','O'],
['O','X','O'],
['X','','O'],
]

board6 = [
['X','X','O'],
['O','X','O'],
['X','',''],
]

def get_winner_list(l):
    if(all(i == 'X' for i in l)):
        return 'X'
    elif()


def get_winner(board):

    winner = None

     ## guides to your approach:
     ## check diagonals
    diag1 = []
    diag2 = []
    col1 = []
    col2 = []
    col3 = []
    for x in range(3):
        diag1.append(board[x][x])
        diag2.append(board[x][-x-1])
        col1.append(board[x][0])
        col2.append(board[x][1])
        col3.append(board[x][2])
    


     ## - how do you go from left to right?
     ## - how do you go from right to left?

     ## check rows

     ## check columns
get_winner(board1)
# Out:
# ['O', 'X', 'O']

# %%
board1 = [
['X','X','O'],
['O','X','O'],
['O','','X'],
]

board2 = [
['X','X','O'],
['O','X','O'],
['','O','X'],
]

board3 = [
['O','X','O'],
['','O','X'],
['X','X','O'],
]

board4 = [
['X','X','X'],
['O','X','O'],
['O','','O'],
]

board5 = [
['X','X','O'],
['O','X','O'],
['X','','O'],
]

board6 = [
['X','X','O'],
['O','X','O'],
['X','',''],
]

def get_winner_list(l):
    if(all(i == 'X' for i in l)):
        return 'X'
    elif(all(i == 'O' for i in l)):
        return 'O'
    else:
        return None


def get_winner(board):

    winner = None

     ## guides to your approach:
     ## check diagonals
    diag1 = []
    diag2 = []
    col1 = []
    col2 = []
    col3 = []
    for x in range(3):
        diag1.append(board[x][x])
        diag2.append(board[x][-x-1])
        col1.append(board[x][0])
        col2.append(board[x][1])
        col3.append(board[x][2])
    winners=[]
    winners.append(get_winner_list(diag1))
    winners.append(get_winner_list(diag2))
    winners.append(get_winner_list(col1))
    winners.append(get_winner_list(col2))
    winners.append(get_winner_list(col3))
    winners.append(get_winner_list(board[0]))
    winners.append(get_winner_list(board[1]))
    winners.append(get_winner_list(board[2]))
    if 'X' in winners:
        return 'X'
    elif 'O' in winners:
        return 'O'
    else:
        return None

     ## - how do you go from left to right?
     ## - how do you go from right to left?

     ## check rows

     ## check columns
print(get_winner(board6))
# Out:
# None

# %%
locations = {
    "admu":{
        "name":"Ateneo de Manila University",
        "latitude":14.6394557,
        "longitude":121.0758975        
    },
    "upd":{
        "name":"University of the Philippines-Diliman Campus",
        "latitude":14.6538519,
        "longitude":121.0663348
    },
    "dlsu":{
        "name":"De La Salle University-Taft",
        "latitude":14.5647346,
        "longitude":120.9909876

    }, # <-- Note that Python does not complain about this extra comma. This is perfectly okay.
       #     The creators of Python saw that dictionaries tend to be changed a lot, so allowing this is a
       #     convenience for developers who need to add elements when needed.
}

legs = {
     ("upd","admu"):{
         "travel_time_mins":10
     },
     ("admu","dlsu"):{
         "travel_time_mins":35
     },
     ("dlsu","upd"):{
         "travel_time_mins":55
     }
}

def eta(source,destination):
    if (source,destination) in legs:
        return legs[(source,destination)]['travel_time_mins']
    else:
        if source == "admu":
            return legs[(source,"dlsu")]['travel_time_mins'] + legs[("dlsu",destination)]['travel_time_mins']
        elif source == "dlsu":
            return legs[(source,"upd")]['travel_time_mins'] + legs[("upd",destination)]['travel_time_mins']
        elif source == "upd":
            return legs[(source,"admu")]['travel_time_mins'] + legs[("admu",destination)]['travel_time_mins']
    
    
    # write your code here
print("ETA: ", eta("dlsu","admu"))
# Out:
# ETA:  65
